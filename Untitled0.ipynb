# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayyagari99/AI_labwork/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1:
# Load the csv file of the dataset into a dataframe

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
pd.reset_option('max_columns')
df = pd.read_csv("/content/mydata.csv")
print(df)
# Out:
#            date  actual_mean_temp  ...  average_precipitation  record_precipitation
# 0      2014-7-1                81  ...                   0.10                  5.91
# 1      2014-7-2                85  ...                   0.10                  1.53
# 2      2014-7-3                82  ...                   0.11                  2.50
# 3      2014-7-4                75  ...                   0.10                  2.63
# 4      2014-7-5                72  ...                   0.10                  1.65
# 5      2014-7-6                74  ...                   0.10                  1.95
# 6      2014-7-7                79  ...                   0.11                  2.37
# 7      2014-7-8                83  ...                   0.11                  1.87
# 8      2014-7-9                80  ...                   0.12                  3.71
# 9     2014-7-10                78  ...                   0.11                  2.45
# ...

# %% [markdown]
# ---
#
#
# # Question 2:
# Find the mean, median, mode, min and max of all numeric attributes

# %%
df.mean(numeric_only=True)
# Out:
# actual_mean_temp           61.049315
# actual_min_temp            49.958904
# actual_max_temp            71.630137
# average_min_temp           48.819178
# average_max_temp           70.983562
# record_min_temp            31.465753
# record_max_temp            88.728767
# record_min_temp_year     1953.279452
# record_max_temp_year     1953.989041
# actual_precipitation        0.102411
# average_precipitation       0.114082
# record_precipitation        2.208904
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# actual_mean_temp           63.00
# actual_min_temp            52.00
# actual_max_temp            73.00
# average_min_temp           48.00
# average_max_temp           72.00
# record_min_temp            30.00
# record_max_temp            90.00
# record_min_temp_year     1963.00
# record_max_temp_year     1953.00
# actual_precipitation        0.00
# average_precipitation       0.11
# record_precipitation        1.98
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    actual_mean_temp  ...  record_precipitation
# 0              78.0  ...                  1.65
# 1               NaN  ...                  1.78
# 2               NaN  ...                  1.82
#
# [3 rows x 12 columns]

# %%
df.min(numeric_only=True)
# Out:
# actual_mean_temp           18.00
# actual_min_temp             7.00
# actual_max_temp            26.00
# average_min_temp           29.00
# average_max_temp           50.00
# record_min_temp            -5.00
# record_max_temp            69.00
# record_min_temp_year     1879.00
# record_max_temp_year     1879.00
# actual_precipitation        0.00
# average_precipitation       0.09
# record_precipitation        0.85
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# actual_mean_temp           88.00
# actual_min_temp            75.00
# actual_max_temp           100.00
# average_min_temp           68.00
# average_max_temp           89.00
# record_min_temp            62.00
# record_max_temp           104.00
# record_min_temp_year     2015.00
# record_max_temp_year     2015.00
# actual_precipitation        2.65
# average_precipitation       0.15
# record_precipitation        6.88
# dtype: float64

# %% [markdown]
# ---
#
#
# # Question 3:
# Print the top 20% of rows showing only the first four columns

# %%
df.iloc[ : int(0.2*len(df)), : 4]
# Out:
#          date  actual_mean_temp  actual_min_temp  actual_max_temp
# 0    2014-7-1                81               70               91
# 1    2014-7-2                85               74               95
# 2    2014-7-3                82               71               93
# 3    2014-7-4                75               64               86
# 4    2014-7-5                72               60               84
# 5    2014-7-6                74               61               87
# 6    2014-7-7                79               67               91
# 7    2014-7-8                83               72               94
# 8    2014-7-9                80               71               89
# 9   2014-7-10                78               71               85
# 10  2014-7-11                78               68               87
# 11  2014-7-12                79               67               91
# 12  2014-7-13                81               69               92
# ...

# %% [markdown]
# ---
#
#
# # Question 4:
# Create a new column (newColumn), with values same as the column 'actual_mean_temp'. Print head of the dataframe.

# %%
df["newColumn"]= df["actual_mean_temp"]
df.head()
# Out:
#        date  actual_mean_temp  ...  record_precipitation  newColumn
# 0  2014-7-1                81  ...                  5.91         81
# 1  2014-7-2                85  ...                  1.53         85
# 2  2014-7-3                82  ...                  2.50         82
# 3  2014-7-4                75  ...                  2.63         75
# 4  2014-7-5                72  ...                  1.65         72
#
# [5 rows x 14 columns]

# %% [markdown]
# ---
#
#
# # Question 5:
# Remove the new column created. Print head of the dataframe

# %%
del df["newColumn"]
df.head()
# Out:
#        date  actual_mean_temp  ...  average_precipitation  record_precipitation
# 0  2014-7-1                81  ...                   0.10                  5.91
# 1  2014-7-2                85  ...                   0.10                  1.53
# 2  2014-7-3                82  ...                   0.11                  2.50
# 3  2014-7-4                75  ...                   0.10                  2.63
# 4  2014-7-5                72  ...                   0.10                  1.65
#
# [5 rows x 13 columns]

# %% [markdown]
# ---
#
#
# # Question 6:
# Print the first 10 rows. Remove the row containing data of '2014-7-3'. Save this row in a variable of type series. Print the first 10 rows after removal.

# %%
df.head(10)
# Out:
#         date  actual_mean_temp  ...  average_precipitation  record_precipitation
# 0   2014-7-1                81  ...                   0.10                  5.91
# 1   2014-7-2                85  ...                   0.10                  1.53
# 2   2014-7-3                82  ...                   0.11                  2.50
# 3   2014-7-4                75  ...                   0.10                  2.63
# 4   2014-7-5                72  ...                   0.10                  1.65
# 5   2014-7-6                74  ...                   0.10                  1.95
# 6   2014-7-7                79  ...                   0.11                  2.37
# 7   2014-7-8                83  ...                   0.11                  1.87
# 8   2014-7-9                80  ...                   0.12                  3.71
# 9  2014-7-10                78  ...                   0.11                  2.45
#
# [10 rows x 13 columns]

# %% [markdown]
# ---
#
#
# # Question 7:
# Add the row deleted before, and print the first 10 rows

# %% [markdown]
# ---
#
#
# # Question 8:
# Update the actual_min_temp in the data row for date ‘2014-7-3’ to any value. Print the updated row.

# %%
#updating new val as 70

df.loc[(df['date'] == '2014-7-3'),'actual_min_temp'] = '70'
df.loc[2,:]
# Out:
# date                     2014-7-3
# actual_mean_temp               82
# actual_min_temp                70
# actual_max_temp                93
# average_min_temp               68
# average_max_temp               89
# record_min_temp                56
# record_max_temp                99
# record_min_temp_year         2010
# record_max_temp_year         1931
# actual_precipitation         0.14
# average_precipitation        0.11
# record_precipitation          2.5
# Name: 2, dtype: object

# %% [markdown]
# ---
#
#
# # Question 9:
# Add 5 to the ‘actual_mean_temp’ wherever the ‘actual_min_temp’ is odd. Do this only on the top 10 rows. Print these 10 rows before and after the operation.

# %% [markdown]
# ---
#
#
# # Question 10:
# 10. Print only those rows where the absolute difference between the ‘record_min_temp_year’ and ‘record_max_temp_year’ is less than 30.
